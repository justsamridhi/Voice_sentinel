# %%
# !git clone https://github.com/Aditya4453/Voice_sentinel.git
# %cd Voice_sentinel
# !pip install -r requirements.txt
# Out:
# Cloning into 'Voice_sentinel'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 112 (delta 36), reused 112 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 61.83 KiB | 904.00 KiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/Voice_sentinel
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 37.1 MB/s eta 0:00:00
# ...

# %%
# !git pull origin main
# Out:
# From https://github.com/Aditya4453/Voice_sentinel
#  * branch            main       -> FETCH_HEAD
# Updating 748dfda..ca6e6be
# error: The following untracked working tree files would be overwritten by merge:
# 	.gradio/certificate.pem
# Please move or remove them before you merge.
# Aborting

# %%
# !python train.py
# Out:
# 2026-07-29 08:45:21.865959: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-07-29 08:45:25] [INFO] [__main__:91]: --- Training VoiceSentinel in Mode A ---
# [2026-07-29 08:45:25] [INFO] [src.data.dataset:62]: Successfully parsed 5 records from ASVspoof2019.LA.protocol.train.txt
# [2026-07-29 08:45:25] [INFO] [src.data.dataset:62]: Successfully parsed 5 records from ASVspoof2019.LA.protocol.dev.txt
# [2026-07-29 08:45:25] [INFO] [src.data.utils:98]: Integrity check passed! Verified 5/5 files.
# [2026-07-29 08:45:25] [INFO] [src.data.utils:49]: --- Dataset Statistics: TRAIN partition ---
# [2026-07-29 08:45:25] [INFO] [src.data.utils:50]: Total Samples: 5
# [2026-07-29 08:45:25] [INFO] [src.data.utils:51]: Bonafide (Real): 1 (20.00%)
# ...

# %%
# !python app.py --share
# Out:
# /content/Voice_sentinel/app.py:355: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme, css. Please pass these parameters to launch() instead.
#   with gr.Blocks(
# 2026-07-29 08:45:44,923 - httpx - INFO - HTTP Request: HEAD https://huggingface.co/api/telemetry/https%3A/api.gradio.app/gradio-initiated-analytics "HTTP/1.1 200 OK"
# 2026-07-29 08:45:44,932 - httpx - INFO - HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# * Running on local URL:  http://127.0.0.1:7860
# 2026-07-29 08:45:45,238 - httpx - INFO - HTTP Request: GET http://127.0.0.1:7860/gradio_api/startup-events "HTTP/1.1 200 OK"
# 2026-07-29 08:45:45,260 - httpx - INFO - HTTP Request: HEAD http://127.0.0.1:7860/ "HTTP/1.1 200 OK"
# 2026-07-29 08:45:45,447 - httpx - INFO - HTTP Request: GET https://api.gradio.app/v3/tunnel-request "HTTP/1.1 200 OK"
# * Running on public URL: https://734019c7b4f054ccff.gradio.live
#
# ...
